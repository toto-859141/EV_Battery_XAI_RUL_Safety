# %% [markdown]
# # EV Battery Data Exploration Starter
#
# Use this notebook to inspect raw datasets, validate columns, and sketch the first preprocessing decisions for RUL and safety modeling.

# %%
from pathlib import Path

PROJECT_ROOT = Path.cwd().resolve().parent
RAW_DATA_DIR = PROJECT_ROOT / "data" / "raw"
PROCESSED_DATA_DIR = PROJECT_ROOT / "data" / "processed"

print("Project root:", PROJECT_ROOT)
print("Raw data directory:", RAW_DATA_DIR)
print("Processed data directory:", PROCESSED_DATA_DIR)

# %%
available_files = sorted(
    path.relative_to(RAW_DATA_DIR)
    for path in RAW_DATA_DIR.rglob("*")
    if path.is_file() and not path.name.startswith(".")
)

available_files[:20]

# %% [markdown]
# ## Suggested next checks
#
# - Load one representative raw file.
# - Inspect time, cycle, voltage, current, and temperature columns.
# - Identify the target definition for RUL and any safety-related labels.
# - Note missing data, sampling intervals, and unit conventions.
